# %% [markdown]
# ## ACTIVIDAD INTEGRADORA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Contexto del Problema
#
# Una empresa de telecomunicaciones quiere analizar los datos de sus clientes para identificar patrones de consumo y detectar posibles cancelaciones de servicio. Se tiene un conjunto de datos con la siguiente información:

# %%
# Cargar datos ficticios
datos = {
"Cliente": ["1", "2", "3", "4", "5"],
"Edad": [25, 40, 32, 22, 25],
"Plan Contratado": ["Básico", "Premium", "Estándar", "Básico", "Premium"],
"Consumo de datos":[5, 50, 10, 7, 45],
"Reclamos en el Último Año":[1, 0, 2, 3, 0],
"Estado de Cuenta": ["Pagado", "Pagado", "Moroso", "Moroso", "Pagado"],
}
df = pd.DataFrame(datos)
df
# Out:
#   Cliente  Edad Plan Contratado  Consumo de datos  Reclamos en el Último Año  \
# 0       1    25          Básico                 5                          1
# 1       2    40         Premium                50                          0
# 2       3    32        Estándar                10                          2
# 3       4    22          Básico                 7                          3
# 4       5    25         Premium                45                          0
#
#   Estado de Cuenta
# 0           Pagado
# 1           Pagado
# 2           Moroso
# 3           Moroso
# 4           Pagado

# %%
#Genera un histograma del consumo de datos (GB) para analizar la distribución
sns.histplot(df["Consumo de datos"], bins=5, kde=True)
plt.show()

# %%
#Crea un gráfico de barras del "Estado de Cuenta" para ver cuántos clientes son morosos.
sns.countplot(x="Estado de Cuenta", data=df)
plt.show()

# %% [markdown]
# ---
# ## 🏆 Actividad Autónoma — EDA Completo de un Nuevo Dataset
#
# > **Para entregar:** Notebook completado subido al aula virtual antes del inicio de la próxima clase.
#
# ### Instrucciones
#
# Elegí **UNO** de estos datasets y realizá un EDA completo:
#
# ```python
# df2 = sns.load_dataset('tips')     # Propinas en restaurante
# df2 = sns.load_dataset('penguins') # Pingüinos de 3 especies
# df2 = sns.load_dataset('diamonds') # Precios de diamantes
# ```
#
# ### Tu análisis debe incluir:
#
# 1. ✅ **Carga y dimensiones** — `head()`, `shape`, `info()`
# 2. ✅ **Estadística descriptiva** — `describe(include='all')`
# 3. ✅ **Análisis de faltantes** — tabla de faltantes y decisión de tratamiento
# 4. ✅ **Al menos 3 visualizaciones** apropiadas para el tipo de variable
# 5. ✅ **Mínimo 3 conclusiones** redactadas en celdas Markdown
# 6. ✅ **Código comentado** en castellano explicando cada bloque
#
# ### Criterios de evaluación
#
# | Criterio | Puntaje |
# |----------|--------|
# | Corrección y funcionalidad del código | 30% |
# | Calidad del análisis y justificación de decisiones | 30% |
# | Visualizaciones pertinentes y bien etiquetadas | 20% |
# | Conclusiones claras y fundamentadas | 20% |
#
# ---

# %%
# Verificar versiones de las librerías principales
#!pip install pandas==3.0
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl

print('Versión del notebook:')

print(f'pandas:     {pd.__version__}')
print(f'numpy:      {np.__version__}')
print(f'matplotlib: {matplotlib.__version__}')
print(f'seaborn:    {sns.__version__}')
print(f'polars:     {pl.__version__}')

# Configuración estética para todos los gráficos del notebook
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['figure.figsize'] = (10, 5)

print('\n✅ Entorno listo')
# Out:
# Versión del notebook:
# pandas:     2.2.2
# numpy:      2.0.2
# matplotlib: 3.10.0
# seaborn:    0.13.2
# polars:     1.35.2
#
# ✅ Entorno listo

# %%
# Carga del dataset desde seaborn (ya disponible en Colab)
df = sns.load_dataset('diamonds') # Precios de diamantes
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
# TODO: exploración inicial — head, info, describe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   53940.000000  53940  53940   53940  53940.000000  53940.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  21551  11292   13065           NaN           NaN
# mean        0.797940    NaN    NaN     NaN     61.749405     57.457184
# std         0.474011    NaN    NaN     NaN      1.432621      2.234491
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         5.010000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# ...

# %%
# TODO: análisis de valores faltantes
# Visualizar distribución de faltantes con heatmap
plt.figure(figsize=(12, 4))
sns.heatmap(
    df.isnull(),
    cbar=False,
    cmap='viridis',
    yticklabels=False
)
plt.title('Mapa de Valores Faltantes (amarillo = NaN, azul = dato presente)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Aclaración: Considero que no es necesario hacer tratamiento de datos faltantes ya que todos los datos están completos.

# %%
# ─── Estudio de datos ────────────────────────────────────────────────────

# Me interesé por estudiar el precio de los diamantes, el mayor precio, el menor y el promedio, para ello realice los calculos y genere un histograma

precio = df['price']

print("El maximo es: ", precio.max()) # valor maximo
print("El mínimo es: ", precio.min()) # valor minimo
print("El promedio es de: ", precio.mean()) # valor promedio
df.hist('price')
# Out:
# El maximo es:  18823
# El mínimo es:  326
# El promedio es de:  3932.799721913237
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
# TODO: visualización 2
cols_numericas = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']
corr_matrix = df[cols_numericas].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,           # Mostrar valores numéricos
    fmt='.2f',            # 2 decimales
    cmap='coolwarm',      # Rojo=positiva, Azul=negativa
    vmin=-1, vmax=1,
    square=True,
    linewidths=0.5
)
plt.title('Matriz de Correlación entre Variables Numéricas', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Gráfico de Barras Comparativo: Precio Promedio por Calidad de Corte (utilice IA como ayuda)

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='color', y='price', palette='viridis')
plt.title('Precio Promedio de Diamantes por Calidad de Corte', fontsize=14)
plt.xlabel('Calidad de Corte', fontsize=12)
plt.ylabel('Precio Promedio', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2455/2524571937.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='color', y='price', palette='viridis')

# %%
# Gráfico de Barras Comparativo: Precio Promedio por Calidad de Corte

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='cut', y='price', palette='viridis')
plt.title('Precio Promedio de Diamantes por Calidad de Corte', fontsize=14)
plt.xlabel('Calidad de Corte', fontsize=12)
plt.ylabel('Precio Promedio', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2455/1142252229.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='cut', y='price', palette='viridis')

# %% [markdown]
# ### 📝 Conclusiones
#
# **Conclusión 1:** Luego de observar el primer histograma vemos una gran concentración de datos en los primeros valores, hay una cantidad muy grande de diamantes con un coste menor a 2500, mientras que podemos observar que algunos llegan a valer más de 17.500 siendo el máximo de 18.823 por ultimo observamos que el promedio es de 3932 y como mencioné anteriormente, esto se debe por la gran concentración de datos de diamantes con un costo muy bajo.
#
# **Conclusión 2:** Quize hacer un estudio de correlación entre las variables numéricas, es decir (peso, profundidad, mesa, precio, y las medidas del diamante "x y z"), llegué a la conclusión que la variable "profundidad" y la variable "mesa", no tienen correlación con las demás variables.
#
#
# **Conclusión 3:** Con los ultimos graficos, encontré algo interesante, el corte no define el precio de los diamantes, sin embargo si su color.
# (grafico 3) Como vemos los diamantes con un color más intenso "E" tienen un promedio de costo más bajo que aquellos que llegan a la categoría "J", pero investigando resulta que esta información es incorrecta, de hecho los diamantes con categoría J son aquellos casi incoloros lo cual en teoría debería disminuir su costo.
#
# (grafico 4) Luego intenté estudiar los diamantes por su tipo de corte, y encontré que el promedio de los diamantes está balanceado en cada tipo de corte, de hecho un corte "Premium" tiene un promedio de costo mayor a un diamante con un tipo de corte "Ideal"
#
# Como conclusión, no puedo asegurar que este ultimo estudio de los diamantes sea correcto, personalmente intentaría buscar datos de diferentes fuentes y volver a realizarlo, ya que los datos no coinciden con la información investigada.
